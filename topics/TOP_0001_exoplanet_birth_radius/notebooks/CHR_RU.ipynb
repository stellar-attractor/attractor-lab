# %% [markdown]
# # Небесные Хроники — Радиус рождения экзопланет

# %% [markdown]
# **Формат:** CHR (3–4 мин)
# **Язык:** РУ
# **Topic:** TOP_0001_exoplanet_birth_radius
# **Build:** `scripts/build_pdf_chr.py`

# %% [markdown]
# **Тезис:**
#
# Планеты редко образуются там, где мы их наблюдаем сегодня; металличность и миграция указывают на галактический «радиус рождения» планетных систем.

# %% [markdown]
# ## Зацепка
#
# Каталоги экзопланет полны планет, расположенных близко к своим звездам.
#
# Но эти тесные орбиты — не места рождения, а конечный результат долгой динамической истории.

# %% [markdown]
# ## Ключевое понятие: металличность
#
# Металличность измеряет содержание тяжелых элементов в звезде-хозяине и обычно выражается как $[\mathrm{Fe/H}]$.
#
# Более высокая металличность означает больше твердого материала в протопланетном диске — это крайне важно для формирования ядер планет.

# %% [markdown]
# Удобное соотношение:
#
# $$
# Z \propto 10^{[\mathrm{Fe/H}]}
# $$

# %% [markdown]
# # Сценарий
#
# Экзопланеты почти никогда не находятся там, где они родились.
#
# Когда мы смотрим на каталоги экзопланет, перед нами — плотные системы,
# где планеты обращаются очень близко к своим звёздам,
# часто с периодами всего в несколько дней.
#
# Но эти орбиты — не место рождения.
# Это финальное состояние сложной и длительной эволюции.
#
# Чтобы понять, где на самом деле формируются планеты,
# нужно выйти за рамки отдельных систем
# и рассматривать их в галактическом контексте.
#
#
# Начнём с металличности — содержания тяжёлых элементов в звёздах-хостах.
#
# На Рисунке~1 показано распределение металличности звёзд,
# у которых обнаружены экзопланеты.
# Выборка охватывает широкий диапазон значений,
# но заметно смещена в сторону высоких металличностей.
#
# Это не случайность.
# Именно тяжёлые элементы формируют твёрдые ядра планет.
#
#
# Прежде чем делать физические выводы,
# необходимо проверить селекционные эффекты.
#
# На Рисунке~2 показана металличность как функция расстояния до системы.
# Здесь нет физического градиента —
# мы видим лишь пределы наблюдательных возможностей.
#
# Экзопланеты легче обнаружить у близких,
# ярких и, как правило, более металличных звёзд.
#
# Это подтверждает, что сама металличность
# не является артефактом наблюдений.
#
#
# Далее рассмотрим свойства самих звёзд.
#
# Рисунки~3 и~4 показывают зависимость металличности
# от эффективной температуры и поверхностной гравитации.
# Большинство звёзд-хостов находятся на главной последовательности,
# и металличность слабо зависит от их эволюционного состояния.
#
# Это важный вывод:
# металличность не формируется в процессе эволюции звезды,
# она отражает условия среды,
# в которой звезда родилась.
#
# Свойства планет усиливают эту картину.
#
# На Рисунке~5 видно,
# что массивные газовые гиганты
# предпочтительно обращаются вокруг металличных звёзд.
# Планеты меньшей массы встречаются
# практически при любых значениях металличности.
#
# Аналогичная картина наблюдается и для радиусов планет
# (Рисунок~6):
# крупные планеты сконцентрированы при высоких металличностях,
# в то время как малые распространены гораздо шире.
#
# Эти зависимости лежат в основе модели аккреции ядра.
# Для формирования массивных планет
# необходимо достаточное количество твёрдого вещества,
# а оно напрямую связано с металличностью.
#
# Наконец, Рисунок~7 показывает динамическую сторону вопроса.
#
# Зависимость массы планеты от орбитального периода
# распадается на несколько характерных популяций.
# Горячие юпитеры занимают короткопериодические орбиты,
# в то время как на больших периодах
# встречается широкий диапазон масс.
#
# Объяснить такую структуру
# исключительно формированием на месте практически невозможно.
# Она указывает на орбитальную миграцию.
#
# Планеты перемещаются.
# Их текущие орбиты
# не совпадают с местами их рождения.
#
# Все эти результаты подводят нас к ключевому вопросу.
#
# Если металличность отражает условия рождения звезды,
# а планеты после формирования мигрируют,
# то определяющим параметром становится
# не текущее положение планеты,
# а то, где в Галактике сформировалась её звезда.
#
# Это и есть идея радиуса рождения планет.
#
# Чтобы по-настоящему понять формирование планет,
# необходимо восстановить орбиты звёзд,
# проследить их движение в диске Млечного Пути
# и связать планетные системы
# с химической эволюцией Галактики.
#
# Именно этим мы займёмся дальше.

# %% [markdown]
# # Данные, использованные в этом эпизоде
#
# Мы объединяем параметры звезд-хозяев из SWEET-Cat со свойствами экзопланет из архива экзопланет NASA (флаг по умолчанию = 1), а затем анализируем тенденции на уровне популяции.

# %% [markdown]
# ## Рисунок 1 — Распределение металличности
#
# ![Распределение металличности звёзд-хостов $[\mathrm{Fe/H}]$](../figures/ru/FIG_001_feh_histogram.png)
#
# Распределение заметно смещено в сторону высоких металличностей — это ключевая подсказка о роли тяжёлых элементов в формировании планет.

# %% [markdown]
# ## Рисунок 2 — Проверка селекционных эффектов по расстоянию
#
# ![Металличность $[\mathrm{Fe/H}]$ как функция расстояния до системы](../figures/ru/FIG_002_feh_vs_distance.png)
#
# Важно отделить физику от наблюдательных эффектов: обнаружение планет проще у близких и ярких звёзд, что может искажать видимую статистику.

# %% [markdown]
# ## Рисунок 3 — Металличность и эффективная температура
#
# ![Металличность $[\mathrm{Fe/H}]$ vs $T_{\mathrm{eff}}$](../figures/ru/FIG_003_feh_vs_teff.png)
#
# Металличность слабо зависит от температуры в пределах выборки, что согласуется с её интерпретацией как «отпечатка» среды рождения звезды.

# %% [markdown]
# ## Рисунок 4 — Металличность и поверхностная гравитация
#
# ![Металличность $[\mathrm{Fe/H}]$ vs $\log g$](../figures/ru/FIG_004_feh_vs_logg.png)
#
# Большая часть звёзд-хостов находится на главной последовательности; заметной зависимости металличности от эволюционного состояния не видно.

# %% [markdown]
# ## Рисунок 5 — Металличность и масса планеты
#
# ![Металличность $[\mathrm{Fe/H}]$ vs масса планеты (в $M_{\mathrm{J}}$)](../figures/ru/FIG_005_feh_vs_planet_mass.png)
#
# Массивные газовые гиганты чаще встречаются у металличных звёзд — это один из опорных результатов в пользу сценария аккреции ядра.

# %% [markdown]
# ## Рисунок 6 — Металличность и радиус планеты
#
# ![Металличность $[\mathrm{Fe/H}]$ vs радиус планеты (в $R_\oplus$)](../figures/ru/FIG_006_feh_vs_planet_radius.png)
#
# Крупные планеты концентрируются при более высоких металличностях, тогда как малые планеты распределены шире по всему диапазону $[\mathrm{Fe/H}]$.

# %% [markdown]
# ## Рисунок 7 — Масса планеты и орбитальный период
#
# ![Масса планеты vs период орбиты](../figures/ru/FIG_007_period_vs_mass.png)
#
# Структура популяций — особенно горячие юпитеры на коротких периодах — трудно объяснима формированием «на месте» и указывает на миграцию.
